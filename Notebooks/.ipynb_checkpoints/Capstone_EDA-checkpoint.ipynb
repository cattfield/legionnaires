# %%
import pandas as pd
import pickle
import xlrd
import numpy as np
import matplotlib.pyplot as plt
from functools import reduce
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-93-aad5c10bbe3b> in <module>
#       5 import matplotlib.pyplot as plt
#       6 from functools import reduce
# ----> 7 from xlsxwriter.utility import xl_rowcol_to_cell
#
# ModuleNotFoundError: No module named 'xlsxwriter'

# %% [markdown]
# PWS_SIZE - Indicates Public Water Systems by size of population served.
# Size	Description
# Very Small	500 or less
# Small	501 - 3,300
# Medium	3,301 - 10,000
# Large	10,001 - 100,000
# Very Large	>100,000

# %% [markdown]
# SERIOUS_VIOLATOR - 'Yes' indicates a public water system with unresolved serious, multiple, and/or continuing violations that is designated as a priority candidate for formal enforcement, as directed by EPA's Drinking Water Enforcement Response Policy (PDF) (16 pp, 952 K). EPA designates systems as serious violators so that the drinking water system and primacy agency will act quickly to resolve the most significant noncompliance. Many public water systems with violations, however, are not serious violators. Operators and the primacy agencies are expected to correct the violations at non-serious violators as well, but without the more strict requirements and deadlines applicable to serious violators. If the violations at a non-serious violator are left uncorrected, that system may become a serious violator. When a serious violator has received formal enforcement action or has returned to compliance, it is no longer designated a serious violator. EPA updates its serious violator list on a quarterly basis.

# %%
serious_violators = pd.read_csv('../data/SDWA_SERIOUS_VIOLATORS.csv')
serious_violators.head(30)
# Out:
#         PWSID                                 PWS_NAME           CITY_SERVED  \
# 0   FL4501229  RIVIERA BEACH UTILITY DISTRICT, CITY OF         RIVIERA BEACH
# 1   AK2299032                         OMNI PARKS STORE            GLENNALLEN
# 2   NJ1708300                 E I DUPONT CHAMBER WORKS  PENNSVILLE TWP.-1708
# 3   NJ1708300                 E I DUPONT CHAMBER WORKS  PENNSVILLE TWP.-1708
# 4   ID1280084               HAUSER LAKE WATER ASSN INC                   NaN
# 5   ID6030036       MARSH VALLEY JR AND SR HIGH SCHOOL                   NaN
# 6   VT0005626                  VALLEY PARK CONDOMINIUM            KILLINGTON
# 7   VT0005626                  VALLEY PARK CONDOMINIUM            KILLINGTON
# 8   VT0005384                  WHIFFLETREE CONDOMINIUM            KILLINGTON
# 9   OK2001036                          MARY JACKSON TP                   NaN
# 10  OK2001036                          MARY JACKSON TP                   NaN
# ...

# %%
serious_violators.shape
# Out:
# (48908, 12)

# %%
serious_violators.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48908 entries, 0 to 48907
# Data columns (total 12 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   PWSID                    48908 non-null  object
#  1   PWS_NAME                 48908 non-null  object
#  2   CITY_SERVED              22217 non-null  object
#  3   STATE                    48908 non-null  object
#  4   STATE_NAME               48902 non-null  object
#  5   PWS_TYPE_CODE            48908 non-null  object
#  6   PWS_TYPE_SHORT           48908 non-null  object
#  7   SOURCE_WATER             48908 non-null  object
#  8   PWS_SIZE                 48908 non-null  object
#  9   POPULATION_SERVED_COUNT  48908 non-null  int64
#  10  FISCAL_YEAR              48908 non-null  int64
#  11  SERIOUS_VIOLATOR         48908 non-null  object
# dtypes: int64(2), object(10)
# memory usage: 4.5+ MB

# %%
serious_violators.describe()
# Out:
#        POPULATION_SERVED_COUNT   FISCAL_YEAR
# count             4.890800e+04  48908.000000
# mean              2.207711e+03   2014.870042
# std               2.654236e+04      2.878089
# min               0.000000e+00   2011.000000
# 25%               5.000000e+01   2012.000000
# 50%               1.320000e+02   2015.000000
# 75%               5.000000e+02   2017.000000
# max               1.661445e+06   2020.000000

# %% [markdown]
# For visual EDA do bar chart of year (x-axis) and counts (y-axis)
# https://echo.epa.gov/help/drinking-water-dashboard-help

# %% [markdown]
# VIOLATION_NAME - Violations required to be reported under SDWA are grouped into the following categories:
# Health-based violations - Violations of maximum contaminant levels (MCLs) or maximum residual disinfectant levels (MRDLs), which specify the highest concentrations of contaminants or disinfectants, respectively, allowed in drinking water; or of treatment technique (TT) rules, which specify required processes intended to reduce the amounts of contaminants in drinking water. MCLs, MRDLs, and treatment technique rules are all health-based drinking water standards.
# Monitoring and reporting (MR) violations - Failure to conduct regular monitoring of drinking water quality, as required by SDWA, or to submit monitoring results in a timely fashion to the state environmental agency or EPA.
# Other violations - Violations of other requirements of SDWA, such as failing to issue annual consumer confidence reports, or conducting periodic sanitary surveys.

# %%
violations = pd.read_csv('../data/SDWA_VIOLATIONS.csv')
# Out:
# /opt/anaconda3/envs/geo/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3063: DtypeWarning: Columns (12) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
violations.head()
# Out:
#        PWSID      PWS_NAME CITY_SERVED STATE STATE_NAME PWS_TYPE_CODE  \
# 0  OK1020515  CHECOTAH PWA         NaN    OK   Oklahoma           CWS
# 1  OK1020515  CHECOTAH PWA         NaN    OK   Oklahoma           CWS
# 2  OK1020515  CHECOTAH PWA         NaN    OK   Oklahoma           CWS
# 3  OK1020515  CHECOTAH PWA         NaN    OK   Oklahoma           CWS
# 4  OK1020515  CHECOTAH PWA         NaN    OK   Oklahoma           CWS
#
#   PWS_TYPE_SHORT SOURCE_WATER PWS_SIZE  POPULATION_SERVED_COUNT  ...  \
# 0      Community           SW   Medium                     3481  ...
# 1      Community           SW   Medium                     3481  ...
# 2      Community           SW   Medium                     3481  ...
# 3      Community           SW   Medium                     3481  ...
# 4      Community           SW   Medium                     3481  ...
#
#                    VIOLATION_NAME VIOLATION_ID RULE_NAME BEGIN_YEAR  END_YEAR  \
# ...

# %%
violations.shape
# Out:
# (3142143, 21)

# %%
violations.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3142143 entries, 0 to 3142142
# Data columns (total 21 columns):
#  #   Column                   Dtype
# ---  ------                   -----
#  0   PWSID                    object
#  1   PWS_NAME                 object
#  2   CITY_SERVED              object
#  3   STATE                    object
#  4   STATE_NAME               object
#  5   PWS_TYPE_CODE            object
#  6   PWS_TYPE_SHORT           object
#  7   SOURCE_WATER             object
#  8   PWS_SIZE                 object
#  9   POPULATION_SERVED_COUNT  int64
#  10  FISCAL_YEAR              int64
#  11  VIOLATION_NAME           object
#  12  VIOLATION_ID             object
#  13  RULE_NAME                object
#  14  BEGIN_YEAR               int64
#  15  END_YEAR                 float64
#  16  RTC_YEAR                 float64
#  17  ACUTE_HEALTH_BASED       object
#  18  HEALTH_BASED             object
#  19  MONITORING_REPORTING     object
# ...

# %%
#violations.describe()

# %%
#df.round({'dogs': 1, 'cats': 0})
#violations.round({'POPULATION_SERVED_COUNT':0, 'FISCAL_YEAR':0, 'BEGIN_YEAR':0, 'END_YEAR':0, 'RTC_YEAR':0})

# %% [markdown]
# # Map out violations
# Find out how many nans there are in city field. See if can create function to map the nan cities using PWS_Name. Is it possible to grab lat & lon from PWS_Name?

# %%
count = violations["CITY_SERVED"].isna().sum()
print(count)
# Out:
# 1734086

# %% [markdown]
# number of entries minus nan values.
# 3,142,143-1,734,086=1,408,057
# so 1,734,086 have nan values in city column (more than half)
# and 1,408,057 have values in city column

# %%
#df.loc[df['Col2'].isnull()] 
nullcity_violations =violations.loc[violations["CITY_SERVED"].isnull()]
nullcity_violations.head(50)
# Out:
#         PWSID                         PWS_NAME CITY_SERVED STATE  \
# 0   OK1020515                     CHECOTAH PWA         NaN    OK
# 1   OK1020515                     CHECOTAH PWA         NaN    OK
# 2   OK1020515                     CHECOTAH PWA         NaN    OK
# 3   OK1020515                     CHECOTAH PWA         NaN    OK
# 4   OK1020515                     CHECOTAH PWA         NaN    OK
# 34  TX0840021          GALVESTON COUNTY MUD 12         NaN    TX
# 35  TX1240001           JIM HOGG COUNTY WCID 2         NaN    TX
# 36  TX1240001           JIM HOGG COUNTY WCID 2         NaN    TX
# 37  TX1240001           JIM HOGG COUNTY WCID 2         NaN    TX
# 38  TX1240001           JIM HOGG COUNTY WCID 2         NaN    TX
# 39  TX1240001           JIM HOGG COUNTY WCID 2         NaN    TX
# 40  TX1240001           JIM HOGG COUNTY WCID 2         NaN    TX
# 41  TX1240001           JIM HOGG COUNTY WCID 2         NaN    TX
# ...

# %% [markdown]
# # Map out violations
# PWSID gives county name - Is it possible to map off of the PWSID instead of city? County would be more accurate. Would have to webscrape each page linked to PWSID number and they all have different URLs.
#
# Make a funtion that itterates over ID and pulls out county from a webpage. ???
#
# Can we maybe focus on one particular State? Do some EDA based on number of state violations.
# First pull in some more data to see if there are addresses anywhere. - No luck so far, see below.

# %%
sdwa_watersystems = pd.read_csv('../data/SDWA_PUB_WATER_SYSTEMS.csv')
sdwa_watersystems.head()
# Out:
#        PWSID  FISCAL_YEAR STATE STATE_NAME  EPA_REGION PWS_TYPE_CODE  \
# 0  AK2210574         2014    AK     Alaska          10           CWS
# 1  AK2210574         2013    AK     Alaska          10           CWS
# 2  AK2210574         2012    AK     Alaska          10           CWS
# 3  AK2210574         2011    AK     Alaska          10           CWS
# 4  OK2004301         2015    OK   Oklahoma           6           CWS
#
#                 PWS_NAME CITY_SERVED STATE_CODE SOURCE_WATER IS_TRIBAL  \
# 0  TOTEM TRAILER TOWN TC   ANCHORAGE         AK           GW         N
# 1  TOTEM TRAILER TOWN TC   ANCHORAGE         AK           GW         N
# 2  TOTEM TRAILER TOWN TC   ANCHORAGE         AK           GW         N
# 3  TOTEM TRAILER TOWN TC   ANCHORAGE         AK           GW         N
# 4           MARIETTA PWA         NaN         OK           GW         N
#
#   SYSTEM_SIZE  POPULATION_SERVED_COUNT
# 0  Very Small                      480
# 1  Very Small                      480
# ...

# %%
sdwa_sitevisits = pd.read_csv('../data/SDWA_SITE_VISITS.csv')
sdwa_sitevisits.head()
# Out:
#        PWSID                PWS_NAME CITY_SERVED STATE STATE_NAME  \
# 0  AK2210574   TOTEM TRAILER TOWN TC   ANCHORAGE    AK     Alaska
# 1  OK2004301            MARIETTA PWA         NaN    OK   Oklahoma
# 2  OK2004301            MARIETTA PWA         NaN    OK   Oklahoma
# 3  FL1464061  EGLIN SITE C-3 (LASER)   EGLIN AFB    FL    Florida
# 4  FL1464061  EGLIN SITE C-3 (LASER)   EGLIN AFB    FL    Florida
#
#   PWS_TYPE_CODE PWS_TYPE_SHORT SOURCE_WATER    PWS_SIZE  \
# 0           CWS      Community           GW  Very Small
# 1           CWS      Community           GW       Small
# 2           CWS      Community           GW       Small
# 3        NTNCWS  Non-Community           GW  Very Small
# 4        NTNCWS  Non-Community           GW  Very Small
#
#    POPULATION_SERVED_COUNT  FISCAL_YEAR SITE_VISIT_DATE SANITARY_SURVEY
# 0                      480         2012      05/18/2012               Y
# 1                     2445         2015      04/15/2015               Y
# ...

# %% [markdown]
# # Initial ideas:
# Count of violations by State
# Chart increase of violations over time (year over year) - see if it correlates with new legislation.
# Focus on a specific region or state - drill down from there.
#
# Possible datasets to pull in: median income, population, age demographics, weather average over time (year over year, month?), coronovirus data?
#
# Datasets to continue: waterbourne illnesses get same counts: count of waterbourne diseases by State, Chart increase of diseases over time (year over year). Focus on a specific region or state - drill down from there.

# %%
violations.STATE_NAME.value_counts()
# Out:
# Texas                                                                                       345999
# Pennsylvania                                                                                311978
# Mississippi                                                                                 230522
# West Virginia                                                                               129322
# Alaska                                                                                      116349
#                                                                                              ...
# Chickasaw Nation, Oklahoma                                                                       1
# Robinson Rancheria of Pomo Indians of California                                                 1
# Big Valley Band of Pomo Indians of the Big Valley Rancheria, California                          1
# ...

# %%
violation_counts = violations.STATE_NAME.value_counts()
violation_counts.head()
# Out:
# Texas            345999
# Pennsylvania     311978
# Mississippi      230522
# West Virginia    129322
# Alaska           116349
# Name: STATE_NAME, dtype: int64

# %% [markdown]
# # Join serious violations with violations

# %%
#all_violations = pd.merge(serious_violators, violations, left_index = True, right_index = True, how = 'inner')
#all_violations.head()
#all_violations.shape

# %%
all_violations = pd.concat([serious_violators, violations])
all_violations.shape
# Out:
# (3191051, 22)

# %%
all_violations.columns
# Out:
# Index(['PWSID', 'PWS_NAME', 'CITY_SERVED', 'STATE', 'STATE_NAME',
#        'PWS_TYPE_CODE', 'PWS_TYPE_SHORT', 'SOURCE_WATER', 'PWS_SIZE',
#        'POPULATION_SERVED_COUNT', 'FISCAL_YEAR', 'SERIOUS_VIOLATOR',
#        'VIOLATION_NAME', 'VIOLATION_ID', 'RULE_NAME', 'BEGIN_YEAR', 'END_YEAR',
#        'RTC_YEAR', 'ACUTE_HEALTH_BASED', 'HEALTH_BASED',
#        'MONITORING_REPORTING', 'PUBLIC_NOTIF_OTHER'],
#       dtype='object')

# %%
all_violations.shape
# Out:
# (3191051, 22)

# %%
all_violations.head()
# Out:
#        PWSID                                 PWS_NAME           CITY_SERVED  \
# 0  FL4501229  RIVIERA BEACH UTILITY DISTRICT, CITY OF         RIVIERA BEACH
# 1  AK2299032                         OMNI PARKS STORE            GLENNALLEN
# 2  NJ1708300                 E I DUPONT CHAMBER WORKS  PENNSVILLE TWP.-1708
# 3  NJ1708300                 E I DUPONT CHAMBER WORKS  PENNSVILLE TWP.-1708
# 4  ID1280084               HAUSER LAKE WATER ASSN INC                   NaN
#
#   STATE  STATE_NAME PWS_TYPE_CODE PWS_TYPE_SHORT SOURCE_WATER    PWS_SIZE  \
# 0    FL     Florida           CWS      Community           GW       Large
# 1    AK      Alaska         TNCWS  Non-Community           GW  Very Small
# 2    NJ  New Jersey        NTNCWS  Non-Community           SW       Small
# 3    NJ  New Jersey        NTNCWS  Non-Community           SW       Small
# 4    ID       Idaho           CWS      Community           GW       Small
#
# ...

# %%
all_violations.to_csv("../data/all_violations.csv", index=False)

# %%
all_violations.columns
# Out:
# Index(['PWSID', 'PWS_NAME', 'CITY_SERVED', 'STATE', 'STATE_NAME',
#        'PWS_TYPE_CODE', 'PWS_TYPE_SHORT', 'SOURCE_WATER', 'PWS_SIZE',
#        'POPULATION_SERVED_COUNT', 'FISCAL_YEAR', 'SERIOUS_VIOLATOR',
#        'VIOLATION_NAME', 'VIOLATION_ID', 'RULE_NAME', 'BEGIN_YEAR', 'END_YEAR',
#        'RTC_YEAR', 'ACUTE_HEALTH_BASED', 'HEALTH_BASED',
#        'MONITORING_REPORTING', 'PUBLIC_NOTIF_OTHER'],
#       dtype='object')

# %%
#type(violation_counts)

# %%
#violation_counts = violation_counts.reset_index()
#violation_counts

# %%
#violation_counts.columns = ['state_name', 'count']
#violation_counts.head(20)

# %%
#serious_violators.STATE_NAME.value_counts()
#serious_violators = serious_violators.STATE_NAME.value_counts()
#serious_violators.head()

# %%
#serious_violators = serious_violators.reset_index()
#serious_violators

# %%
#serious_violators.columns = ['state_name', 'count']
#serious_violators.head(20)

# %% [markdown]
# # Take a look at waterbourne disease data

# %%
#water_2018 = pd.read_csv("../data/2018-table2h.csv")
#water_2018.head()

# %%
#this data is from years 1998-2017
water_outbreaks = pd.read_excel("../data/NationalOutbreakPublicDataTool.xlsx")
water_outbreaks.tail()
# Out:
#      Year Month      State Primary Mode                 Etiology  \
# 738  2015   Dec    Florida        Water   Legionella pneumophila
# 739  2015   Dec    Georgia        Water   Legionella pneumophila
# 740  2015   Dec    Georgia        Water   Legionella pneumophila
# 741  2017   Dec  Wisconsin        Water             Chlorine Gas
# 742  2010   Jan    Vermont        Water  Cryptosporidium unknown
#
#     Serotype or Genotype Etiology Status                      Setting  \
# 738          serogroup 1       Confirmed        Hotel/Motel/Lodge/Inn
# 739                  NaN       Suspected         Hospital/Health Care
# 740          serogroup 1       Suspected  Factory/Industrial Facility
# 741                  NaN       Suspected        Recreational facility
# 742                  NaN       Confirmed        Vacation rental house
#
#      Illnesses  Hospitalizations  ...  Deaths  Info on Deaths  Food Vehicle  \
# ...

# %%
water_outbreaks.shape
# Out:
# (743, 21)

# %%
#legionella_2017 = dr_utilization_2017[dr_utilization_2017['HCPCS Code'] == 86717]
#legionella = water_outbreaks[water_outbreaks['Etiology'] == 'Legionella']
#legionella.head()
legionella = water_outbreaks[water_outbreaks['Etiology'].str.contains('Legionella')]
legionella.shape
#df1 = df[df['Position'].str.contains("PG") & df['College'].str.contains('UC')] 
#df1
# Out:
# (290, 21)

# %%
legionella.head()
# Out:
#    Year Month         State Primary Mode                Etiology  \
# 1  2011   Jan          Ohio        Water  Legionella pneumophila
# 4  2011   Jan    Washington        Water  Legionella pneumophila
# 5  2012   Jan  Pennsylvania        Water  Legionella pneumophila
# 6  2012   Jan      New York        Water  Legionella pneumophila
# 7  2010   Jan          Ohio        Water  Legionella pneumophila
#
#   Serotype or Genotype Etiology Status                Setting  Illnesses  \
# 1          serogroup 1       Confirmed   Hospital/Health Care         11
# 4          serogroup 1       Confirmed   Hospital/Health Care          3
# 5          serogroup 1       Confirmed  Hotel/Motel/Lodge/Inn          2
# 6          serogroup 1       Confirmed  Hotel/Motel/Lodge/Inn          3
# 7          serogroup 1       Confirmed   Hospital/Health Care          4
#
#    Hospitalizations  ...  Deaths  Info on Deaths  Food Vehicle  \
# 1              11.0  ...     1.0            11.0           NaN
# ...

# %%
#df['DataFrame Column'] = df['DataFrame Column'].apply(str)
legionella['Month'] = legionella['Month'].apply(str)
# Out:
# /opt/anaconda3/envs/geo/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
legionella.to_csv("../data/legionella.csv", index=False)

# %% [markdown]
# # Call in cdc waterborne diseases weekly reports

# %%
col_df = pd.read_csv('../data/2016-table2h.txt', sep=r'\\t', engine='python', skiprows = 3, nrows = 9)
columns = [col for col in col_df['Reporting Area']]
print(columns)
# Out:
# ['Human immunodeficiency virus diagnoses', 'Influenza-associated pediatric mortality', 'Invasive pneumococcal disease, All ages, Confirmed', 'Invasive pneumococcal disease, All ages, Probable', 'Invasive pneumococcal disease, Age <5 years, Confirmed', 'Invasive pneumococcal disease, Age <5 years, Probable', 'Legionellosis', 'Leptospirosis']

# %%
read_txt_file_2016 = pd.read_csv('../data/2016-table2h.txt', sep='\\\t', names=columns, engine='python', skiprows = 14).reset_index()
read_txt_file_2016.head()
# Out:
#            index Human immunodeficiency virus diagnoses  \
# 0  United States                                 34,775
# 1    New England                                    966
# 2    Connecticut                                    201
# 3          Maine                                     43
# 4  Massachusetts                                    607
#
#   Influenza-associated pediatric mortality  \
# 0                                       82
# 1                                        4
# 2                                        �
# 3                                        1
# 4                                        2
#
#   Invasive pneumococcal disease, All ages, Confirmed  \
# 0                                             17,603
# 1                                              1,106
# 2                                                239
# 3                                                133
# 4                                                513
#
# ...

# %% [markdown]
# # Get rid of the � sign

# %%
read_txt_file_2016['Influenza-associated pediatric mortality'] = read_txt_file_2016['Influenza-associated pediatric mortality'].replace('�', np.nan)
read_txt_file_2016.head()
# Out:
#            index Human immunodeficiency virus diagnoses  \
# 0  United States                                 34,775
# 1    New England                                    966
# 2    Connecticut                                    201
# 3          Maine                                     43
# 4  Massachusetts                                    607
#
#   Influenza-associated pediatric mortality  \
# 0                                       82
# 1                                        4
# 2                                      NaN
# 3                                        1
# 4                                        2
#
#   Invasive pneumococcal disease, All ages, Confirmed  \
# 0                                             17,603
# 1                                              1,106
# 2                                                239
# 3                                                133
# 4                                                513
#
# ...

# %%
#read_txt_file['Influenza-associated pediatric mortality'].value_counts()

# %%
read_txt_file_2016 = read_txt_file_2016.replace('�', np.nan)
read_txt_file_2016.head()
# Out:
#            index Human immunodeficiency virus diagnoses  \
# 0  United States                                 34,775
# 1    New England                                    966
# 2    Connecticut                                    201
# 3          Maine                                     43
# 4  Massachusetts                                    607
#
#   Influenza-associated pediatric mortality  \
# 0                                       82
# 1                                        4
# 2                                      NaN
# 3                                        1
# 4                                        2
#
#   Invasive pneumococcal disease, All ages, Confirmed  \
# 0                                             17,603
# 1                                              1,106
# 2                                                239
# 3                                                133
# 4                                                513
#
# ...

# %%
read_txt_file_2016['Year'] = '2016'
read_txt_file_2016.head(2)
# Out:
#            index Human immunodeficiency virus diagnoses  \
# 0  United States                                 34,775
# 1    New England                                    966
#
#   Influenza-associated pediatric mortality  \
# 0                                       82
# 1                                        4
#
#   Invasive pneumococcal disease, All ages, Confirmed  \
# 0                                             17,603
# 1                                              1,106
#
#   Invasive pneumococcal disease, All ages, Probable  \
# 0                                                23
# 1                                               NaN
#
#   Invasive pneumococcal disease, Age <5 years, Confirmed  \
# 0                                              1,137
# 1                                                 58
#
#   Invasive pneumococcal disease, Age <5 years, Probable Legionellosis  \
# 0                                                  5            6,141
# ...

# %%
legion_2016 = read_txt_file_2016
legion_2016.head(2)
# Out:
#            index Human immunodeficiency virus diagnoses  \
# 0  United States                                 34,775
# 1    New England                                    966
#
#   Influenza-associated pediatric mortality  \
# 0                                       82
# 1                                        4
#
#   Invasive pneumococcal disease, All ages, Confirmed  \
# 0                                             17,603
# 1                                              1,106
#
#   Invasive pneumococcal disease, All ages, Probable  \
# 0                                                23
# 1                                               NaN
#
#   Invasive pneumococcal disease, Age <5 years, Confirmed  \
# 0                                              1,137
# 1                                                 58
#
#   Invasive pneumococcal disease, Age <5 years, Probable Legionellosis  \
# 0                                                  5            6,141
# ...

# %%
col_df = pd.read_csv('../data/2017-table2h.txt', sep=r'\\t', engine='python', skiprows = 3, nrows = 9)
columns = [col for col in col_df['Reporting Area']]
print(columns)
# Out:
# ['Human immunodeficiency virus diagnoses', 'Influenza-associated pediatric mortality', 'Invasive pneumococcal disease, All ages, Confirmed *', 'Invasive pneumococcal disease, All ages, Probable *', 'Invasive pneumococcal disease, Age <5 years, Confirmed *', 'Invasive pneumococcal disease, Age <5 years, Probable *', 'Legionellosis', 'Leptospirosis']

# %%
read_txt_file_2017 = pd.read_csv('../data/2017-table2h.txt', sep='\\\t', names=columns, engine='python', skiprows = 14).reset_index()
read_txt_file_2017.head()
# Out:
#            index Human immunodeficiency virus diagnoses  \
# 0  United States                                 33,938
# 1    New England                                    900
# 2    Connecticut                                    232
# 3          Maine                                     25
# 4  Massachusetts                                    516
#
#   Influenza-associated pediatric mortality  \
# 0                                      126
# 1                                        5
# 2                                        1
# 3                                        �
# 4                                        2
#
#   Invasive pneumococcal disease, All ages, Confirmed *  \
# 0                                             19,620
# 1                                              1,222
# 2                                                262
# 3                                                141
# 4                                                590
#
# ...

# %%
read_txt_file_2017 = read_txt_file_2017.replace('�', np.nan)
read_txt_file_2017.head(3)
# Out:
#            index Human immunodeficiency virus diagnoses  \
# 0  United States                                 33,938
# 1    New England                                    900
# 2    Connecticut                                    232
#
#   Influenza-associated pediatric mortality  \
# 0                                      126
# 1                                        5
# 2                                        1
#
#   Invasive pneumococcal disease, All ages, Confirmed *  \
# 0                                             19,620
# 1                                              1,222
# 2                                                262
#
#   Invasive pneumococcal disease, All ages, Probable *  \
# 0                                                160
# 1                                                  5
# 2                                                  5
#
#   Invasive pneumococcal disease, Age <5 years, Confirmed *  \
# 0                                              1,220
# ...

# %%
read_txt_file_2017['Year'] = '2017'
read_txt_file_2017.head(2)
# Out:
#            index Human immunodeficiency virus diagnoses  \
# 0  United States                                 33,938
# 1    New England                                    900
#
#   Influenza-associated pediatric mortality  \
# 0                                      126
# 1                                        5
#
#   Invasive pneumococcal disease, All ages, Confirmed *  \
# 0                                             19,620
# 1                                              1,222
#
#   Invasive pneumococcal disease, All ages, Probable *  \
# 0                                                160
# 1                                                  5
#
#   Invasive pneumococcal disease, Age <5 years, Confirmed *  \
# 0                                              1,220
# 1                                                 49
#
#   Invasive pneumococcal disease, Age <5 years, Probable * Legionellosis  \
# 0                                                 14              7,458
# ...

# %%
legion_2017 = read_txt_file_2017
legion_2017.head(2)
# Out:
#            index Human immunodeficiency virus diagnoses  \
# 0  United States                                 33,938
# 1    New England                                    900
#
#   Influenza-associated pediatric mortality  \
# 0                                      126
# 1                                        5
#
#   Invasive pneumococcal disease, All ages, Confirmed *  \
# 0                                             19,620
# 1                                              1,222
#
#   Invasive pneumococcal disease, All ages, Probable *  \
# 0                                                160
# 1                                                  5
#
#   Invasive pneumococcal disease, Age <5 years, Confirmed *  \
# 0                                              1,220
# 1                                                 49
#
#   Invasive pneumococcal disease, Age <5 years, Probable * Legionellosis  \
# 0                                                 14              7,458
# ...

# %%
col_df = pd.read_csv('../data/2018-table2h.txt', sep=r'\\t', engine='python', skiprows = 3, nrows = 9)
columns = [col for col in col_df['Reporting Area']]
print(columns)
# Out:
# ['Human immunodeficiency virus diagnoses', 'Influenza-associated pediatric mortality', 'Invasive pneumococcal disease, All ages, Confirmed *', 'Invasive pneumococcal disease, All ages, Probable *', 'Invasive pneumococcal disease, Age <5 years, Confirmed *', 'Invasive pneumococcal disease, Age <5 years, Probable *', 'Legionellosis', 'Leptospirosis']

# %%
read_txt_file_2018 = pd.read_csv('../data/2018-table2h.txt', sep='\\\t', names=columns, engine='python', skiprows = 14).reset_index()
read_txt_file_2018.head()
# Out:
#            index Human immunodeficiency virus diagnoses  \
# 0  United States                                 32,999
# 1    New England                                    938
# 2    Connecticut                                    208
# 3          Maine                                     26
# 4  Massachusetts                                    583
#
#   Influenza-associated pediatric mortality  \
# 0                                      159
# 1                                        6
# 2                                        4
# 3                                        �
# 4                                        1
#
#   Invasive pneumococcal disease, All ages, Confirmed *  \
# 0                                             19,619
# 1                                              1,134
# 2                                                252
# 3                                                132
# 4                                                506
#
# ...

# %%
read_txt_file_2018 = read_txt_file_2018.replace('�', np.nan)
read_txt_file_2018.head(2)
# Out:
#            index Human immunodeficiency virus diagnoses  \
# 0  United States                                 32,999
# 1    New England                                    938
#
#   Influenza-associated pediatric mortality  \
# 0                                      159
# 1                                        6
#
#   Invasive pneumococcal disease, All ages, Confirmed *  \
# 0                                             19,619
# 1                                              1,134
#
#   Invasive pneumococcal disease, All ages, Probable *  \
# 0                                                238
# 1                                                  8
#
#   Invasive pneumococcal disease, Age <5 years, Confirmed *  \
# 0                                              1,078
# 1                                                 46
#
#   Invasive pneumococcal disease, Age <5 years, Probable * Legionellosis  \
# 0                                                 38              9,933
# ...

# %%
read_txt_file_2018['Year'] = '2018'
read_txt_file_2018.head(2)
# Out:
#            index Human immunodeficiency virus diagnoses  \
# 0  United States                                 32,999
# 1    New England                                    938
#
#   Influenza-associated pediatric mortality  \
# 0                                      159
# 1                                        6
#
#   Invasive pneumococcal disease, All ages, Confirmed *  \
# 0                                             19,619
# 1                                              1,134
#
#   Invasive pneumococcal disease, All ages, Probable *  \
# 0                                                238
# 1                                                  8
#
#   Invasive pneumococcal disease, Age <5 years, Confirmed *  \
# 0                                              1,078
# 1                                                 46
#
#   Invasive pneumococcal disease, Age <5 years, Probable * Legionellosis  \
# 0                                                 38              9,933
# ...

# %%
legion_2018 = read_txt_file_2018
legion_2018.head(2)
# Out:
#            index Human immunodeficiency virus diagnoses  \
# 0  United States                                 32,999
# 1    New England                                    938
#
#   Influenza-associated pediatric mortality  \
# 0                                      159
# 1                                        6
#
#   Invasive pneumococcal disease, All ages, Confirmed *  \
# 0                                             19,619
# 1                                              1,134
#
#   Invasive pneumococcal disease, All ages, Probable *  \
# 0                                                238
# 1                                                  8
#
#   Invasive pneumococcal disease, Age <5 years, Confirmed *  \
# 0                                              1,078
# 1                                                 46
#
#   Invasive pneumococcal disease, Age <5 years, Probable * Legionellosis  \
# 0                                                 38              9,933
# ...

# %%
#concat_data = pd.concat([legion_2016, legion_2017, legion_2018])
#concat_data.head()

# %%
concat_data.columns
# Out:
# Index(['Human immunodeficiency virus diagnoses',
#        'Influenza-associated pediatric mortality',
#        'Invasive pneumococcal disease, All ages, Confirmed',
#        'Invasive pneumococcal disease, All ages, Probable',
#        'Invasive pneumococcal disease, Age <5 years, Confirmed',
#        'Invasive pneumococcal disease, Age <5 years, Probable',
#        'Legionellosis', 'Leptospirosis', 'Year',
#        'Invasive pneumococcal disease, All ages, Confirmed *',
#        'Invasive pneumococcal disease, All ages, Probable *',
#        'Invasive pneumococcal disease, Age <5 years, Confirmed *',
#        'Invasive pneumococcal disease, Age <5 years, Probable *'],
#       dtype='object')

# %%
#data_frames = [legion_11_10, legion_13_12, legion_14_15]

#legion_2010_to_2015 = reduce(lambda left,right: pd.merge(left, right, on=['index'], how='outer'), data_frames)
#legion_2010_to_2015.head()

data_frames = [legion_2016, legion_2017, legion_2018]

legion_2016_to_2018 = reduce(lambda left,right: pd.merge(left, right, on=['index'], how='outer'), data_frames)
legion_2016_to_2018.head()
# Out:
#            index Human immunodeficiency virus diagnoses_x  \
# 0  United States                                   34,775
# 1    New England                                      966
# 2    Connecticut                                      201
# 3          Maine                                       43
# 4  Massachusetts                                      607
#
#   Influenza-associated pediatric mortality_x  \
# 0                                         82
# 1                                          4
# 2                                        NaN
# 3                                          1
# 4                                          2
#
#   Invasive pneumococcal disease, All ages, Confirmed  \
# 0                                             17,603
# 1                                              1,106
# 2                                                239
# 3                                                133
# 4                                                513
#
# ...

# %%
legion_2016_to_2018.columns
# Out:
# Index(['index', 'Human immunodeficiency virus diagnoses_x',
#        'Influenza-associated pediatric mortality_x',
#        'Invasive pneumococcal disease, All ages, Confirmed',
#        'Invasive pneumococcal disease, All ages, Probable',
#        'Invasive pneumococcal disease, Age <5 years, Confirmed',
#        'Invasive pneumococcal disease, Age <5 years, Probable',
#        'Legionellosis_x', 'Leptospirosis_x', 'Year_x',
#        'Human immunodeficiency virus diagnoses_y',
#        'Influenza-associated pediatric mortality_y',
#        'Invasive pneumococcal disease, All ages, Confirmed *_x',
#        'Invasive pneumococcal disease, All ages, Probable *_x',
#        'Invasive pneumococcal disease, Age <5 years, Confirmed *_x',
#        'Invasive pneumococcal disease, Age <5 years, Probable *_x',
#        'Legionellosis_y', 'Leptospirosis_y', 'Year_y',
#        'Human immunodeficiency virus diagnoses',
#        'Influenza-associated pediatric mortality',
# ...

# %%
legion_2016_to_2018 = legion_2016_to_2018.drop(columns = ['Human immunodeficiency virus diagnoses_x',
       'Influenza-associated pediatric mortality_x',
       'Invasive pneumococcal disease, All ages, Confirmed',
       'Invasive pneumococcal disease, All ages, Probable',
       'Invasive pneumococcal disease, Age <5 years, Confirmed',
       'Invasive pneumococcal disease, Age <5 years, Probable','Leptospirosis_x', 'Human immunodeficiency virus diagnoses_y',
       'Influenza-associated pediatric mortality_y',
       'Invasive pneumococcal disease, All ages, Confirmed *_x',
       'Invasive pneumococcal disease, All ages, Probable *_x',
       'Invasive pneumococcal disease, Age <5 years, Confirmed *_x',
       'Invasive pneumococcal disease, Age <5 years, Probable *_x', 'Leptospirosis_y', 'Human immunodeficiency virus diagnoses',
       'Influenza-associated pediatric mortality',
       'Invasive pneumococcal disease, All ages, Confirmed *_y',
       'Invasive pneumococcal disease, All ages, Probable *_y',
       'Invasive pneumococcal disease, Age <5 years, Confirmed *_y',
       'Invasive pneumococcal disease, Age <5 years, Probable *_y', 'Leptospirosis',])
legion_2016_to_2018.head()
# Out:
#            index Legionellosis_x Year_x Legionellosis_y Year_y Legionellosis  \
# 0  United States           6,141   2016           7,458   2017         9,933
# 1    New England             310   2016             472   2017           767
# 2    Connecticut              78   2016             120   2017           198
# 3          Maine              16   2016              16   2017            34
# 4  Massachusetts             141   2016             201   2017           368
#
#    Year
# 0  2018
# 1  2018
# 2  2018
# 3  2018
# 4  2018

# %%
#legion_16_17_18.to_excel("../data/legion_16_17_18.xlsx", index=True)

legion_2016_to_2018.to_excel("../data/legion_2016_to_2018.xlsx", index=True)

# %%
legion_16_17 = concat_data.drop(columns = ['Human immunodeficiency virus diagnoses', 'Influenza-associated pediatric mortality',
       'Invasive pneumococcal disease, All ages, Confirmed',
       'Invasive pneumococcal disease, All ages, Probable',
       'Invasive pneumococcal disease, Age <5 years, Confirmed',
       'Invasive pneumococcal disease, Age <5 years, Probable', 'Leptospirosis', 'Invasive pneumococcal disease, All ages, Confirmed *',
       'Invasive pneumococcal disease, All ages, Probable *',
       'Invasive pneumococcal disease, Age <5 years, Confirmed *',
       'Invasive pneumococcal disease, Age <5 years, Probable *'])
legion_16_17.head()
# Out:
#               Legionellosis  Year
# United States         6,141  2016
# New England             310  2016
# Connecticut              78  2016
# Maine                    16  2016
# Massachusetts           141  2016

# %%
legion_16_17.tail()
# Out:
#                                                    Legionellosis  Year
# Suggested Citation:                                         None  2017
# Centers for Disease Control and Prevention. Nat...          None  2017
# Available at: https://www.cdc.gov/nndss/infecti...          None  2017
# https://wwwn.cdc.gov/nndss/, National Notifiabl...          None  2017
# Provided by https://wonder.cdc.gov, CDC WONDER              None  2017

# %%
legion_16_17_18 = concat_data.drop(columns = ['Human immunodeficiency virus diagnoses', 'Influenza-associated pediatric mortality',
       'Invasive pneumococcal disease, All ages, Confirmed',
       'Invasive pneumococcal disease, All ages, Probable',
       'Invasive pneumococcal disease, Age <5 years, Confirmed',
       'Invasive pneumococcal disease, Age <5 years, Probable', 'Leptospirosis', 'Invasive pneumococcal disease, All ages, Confirmed *',
       'Invasive pneumococcal disease, All ages, Probable *',
       'Invasive pneumococcal disease, Age <5 years, Confirmed *',
       'Invasive pneumococcal disease, Age <5 years, Probable *'])
legion_16_17_18.head()
# Out:
#               Legionellosis  Year
# United States         6,141  2016
# New England             310  2016
# Connecticut              78  2016
# Maine                    16  2016
# Massachusetts           141  2016

# %%
legion_16_17.to_excel("../data/legion_16_17.xlsx", index=True)

# %%
legion_16_17_18.to_excel("../data/legion_16_17_18.xlsx", index=True)

# %% [markdown]
# # Get legionnaires data off of tables for years 2015-2011

# %%
col_df = pd.read_csv('../data/TABLE_II_Part6_2011_week52.txt', sep=r'\\t', engine='python', skiprows = 4, nrows = 16)
columns = [col for col in col_df['Reporting Area']]
print(columns)
# Out:
# ['Legionellosis current week', 'Legionellosis previous 52 weeks median', 'Legionellosis previous 52 weeks maximum', 'Legionellosis cummulative for 2011', 'Legionellosis cummulative for 2010', 'Lyme disease current week', 'Lyme disease previous 52 weeks median', 'Lyme disease previous 52 weeks maximum', 'Lyme disease cummulative for 2011', 'Lyme disease cummulative for 2010', 'Malaria current week', 'Malaria previous 52 weeks median', 'Malaria previous 52 weeks maximum', 'Malaria cummulative for 2011', 'Malaria cummulative for 2010']

# %%
read_legion_2011_2010 = pd.read_csv('../data/TABLE_II_Part6_2011_week52.txt', sep='\\\t', names=columns, engine='python', skiprows = 22).reset_index()
read_legion_2011_2010.head(2)
# Out:
#            index Legionellosis current week  \
# 0  UNITED STATES                         31
# 1    NEW ENGLAND                          -
#
#   Legionellosis previous 52 weeks median  \
# 0                                     61
# 1                                      5
#
#   Legionellosis previous 52 weeks maximum Legionellosis cummulative for 2011  \
# 0                                     161                              3,676
# 1                                      39                                394
#
#   Legionellosis cummulative for 2010 Lyme disease current week  \
# 0                              3,346                        94
# 1                                274                         3
#
#   Lyme disease previous 52 weeks median  \
# 0                                   350
# 1                                    78
#
#   Lyme disease previous 52 weeks maximum Lyme disease cummulative for 2011  \
# ...

# %%
read_legion_2011_2010.columns
# Out:
# Index(['index', 'Legionellosis current week',
#        'Legionellosis previous 52 weeks median',
#        'Legionellosis previous 52 weeks maximum',
#        'Legionellosis cummulative for 2011',
#        'Legionellosis cummulative for 2010', 'Lyme disease current week',
#        'Lyme disease previous 52 weeks median',
#        'Lyme disease previous 52 weeks maximum',
#        'Lyme disease cummulative for 2011',
#        'Lyme disease cummulative for 2010', 'Malaria current week',
#        'Malaria previous 52 weeks median', 'Malaria previous 52 weeks maximum',
#        'Malaria cummulative for 2011', 'Malaria cummulative for 2010'],
#       dtype='object')

# %%
legion_11_10= read_legion_2011_2010.drop(columns = ['Legionellosis current week', 'Legionellosis previous 52 weeks median',
       'Legionellosis previous 52 weeks maximum', 'Lyme disease current week',
       'Lyme disease previous 52 weeks median',
       'Lyme disease previous 52 weeks maximum',
       'Lyme disease cummulative for 2011',
       'Lyme disease cummulative for 2010', 'Malaria current week',
       'Malaria previous 52 weeks median', 'Malaria previous 52 weeks maximum',
       'Malaria cummulative for 2011', 'Malaria cummulative for 2010',])
legion_11_10.head(2)
# Out:
#            index Legionellosis cummulative for 2011  \
# 0  UNITED STATES                              3,676
# 1    NEW ENGLAND                                394
#
#   Legionellosis cummulative for 2010
# 0                              3,346
# 1                                274

# %%
col_df = pd.read_csv('../data/TABLE_II_Part6_2013_week52.txt', sep=r'\\t', engine='python', skiprows = 4, nrows = 16)
columns = [col for col in col_df['Reporting Area']]
print(columns)
# Out:
# ['Legionellosis current week', 'Legionellosis previous 52 weeks median', 'Legionellosis previous 52 weeks maximum', 'Legionellosis cummulative for 2013', 'Legionellosis cummulative for 2012', 'Lyme disease current week', 'Lyme disease previous 52 weeks median', 'Lyme disease previous 52 weeks maximum', 'Lyme disease cummulative for 2013', 'Lyme disease cummulative for 2012', 'Malaria current week', 'Malaria previous 52 weeks median', 'Malaria previous 52 weeks maximum', 'Malaria cummulative for 2013', 'Malaria cummulative for 2012']

# %%
read_legion_2013_2012 = pd.read_csv('../data/TABLE_II_Part6_2013_week52.txt', sep='\\\t', names=columns, engine='python', skiprows = 22).reset_index()
read_legion_2013_2012.head(2)
# Out:
#            index Legionellosis current week  \
# 0  UNITED STATES                         20
# 1    NEW ENGLAND                          1
#
#   Legionellosis previous 52 weeks median  \
# 0                                     63
# 1                                      5
#
#   Legionellosis previous 52 weeks maximum Legionellosis cummulative for 2013  \
# 0                                     258                              4,548
# 1                                      25                                335
#
#   Legionellosis cummulative for 2012 Lyme disease current week  \
# 0                              3,688                        56
# 1                                308                         1
#
#   Lyme disease previous 52 weeks median  \
# 0                                   347
# 1                                   108
#
#   Lyme disease previous 52 weeks maximum Lyme disease cummulative for 2013  \
# ...

# %%
read_legion_2013_2012.columns
# Out:
# Index(['index', 'Legionellosis current week',
#        'Legionellosis previous 52 weeks median',
#        'Legionellosis previous 52 weeks maximum',
#        'Legionellosis cummulative for 2013',
#        'Legionellosis cummulative for 2012', 'Lyme disease current week',
#        'Lyme disease previous 52 weeks median',
#        'Lyme disease previous 52 weeks maximum',
#        'Lyme disease cummulative for 2013',
#        'Lyme disease cummulative for 2012', 'Malaria current week',
#        'Malaria previous 52 weeks median', 'Malaria previous 52 weeks maximum',
#        'Malaria cummulative for 2013', 'Malaria cummulative for 2012'],
#       dtype='object')

# %%
legion_13_12 = read_legion_2013_2012.drop(columns = ['Legionellosis current week',
       'Legionellosis previous 52 weeks median',
       'Legionellosis previous 52 weeks maximum','Lyme disease current week',
       'Lyme disease previous 52 weeks median',
       'Lyme disease previous 52 weeks maximum',
       'Lyme disease cummulative for 2013',
       'Lyme disease cummulative for 2012', 'Malaria current week',
       'Malaria previous 52 weeks median', 'Malaria previous 52 weeks maximum',
       'Malaria cummulative for 2013', 'Malaria cummulative for 2012'])
legion_13_12.head()
# Out:
#            index Legionellosis cummulative for 2013  \
# 0  UNITED STATES                              4,548
# 1    NEW ENGLAND                                335
# 2          Conn.                                 59
# 3          Maine                                 19
# 4          Mass.                                185
#
#   Legionellosis cummulative for 2012
# 0                              3,688
# 1                                308
# 2                                 55
# 3                                 18
# 4                                173

# %%
col_df = pd.read_csv('../data/TABLE_II_Part7_2015_week52.txt', sep=r'\\t', engine='python', skiprows = 4, nrows = 16)
columns = [col for col in col_df['Reporting Area']]
print(columns)
# Out:
# ['Invasive Pneumococcal�, All Ages Disease current week', 'Invasive Pneumococcal�, All Ages previous 52 weeks median', 'Invasive Pneumococcal�, All Ages previous 52 weeks maximum', 'Invasive Pneumococcal�, All Ages cummulative for 2015', 'Invasive Pneumococcal�, All Ages cummulative for 2014', 'Invasive Pneumococcal�, Age <5 years current week', 'Invasive Pneumococcal�, Age <5 years previous 52 weeks median', 'Invasive Pneumococcal�, Age <5 years previous 52 weeks maximum', 'Invasive Pneumococcal�, Age <5 years cummulative for 2015', 'Invasive Pneumococcal�, Age <5 years cummulative for 2014', 'Legionellosis current week', 'Legionellosis previous 52 weeks median', 'Legionellosis previous 52 weeks maximum', 'Legionellosis cummulative for 2015', 'Legionellosis cummulative for 2014']

# %%
read_legion_2014_2015 = pd.read_csv('../data/TABLE_II_Part7_2015_week52.txt', sep='\\\t', names=columns, engine='python', skiprows = 22).reset_index()
read_legion_2014_2015.head(2)
# Out:
#            index Invasive Pneumococcal�, All Ages Disease current week  \
# 0  UNITED STATES                                                173
# 1    NEW ENGLAND                                                  3
#
#   Invasive Pneumococcal�, All Ages previous 52 weeks median  \
# 0                                                265
# 1                                                 19
#
#   Invasive Pneumococcal�, All Ages previous 52 weeks maximum  \
# 0                                                761
# 1                                                 55
#
#   Invasive Pneumococcal�, All Ages cummulative for 2015  \
# 0                                             14,714
# 1                                                971
#
#   Invasive Pneumococcal�, All Ages cummulative for 2014  \
# 0                                             14,595
# 1                                              1,081
#
#   Invasive Pneumococcal�, Age <5 years current week  \
# ...

# %%
read_legion_2014_2015.columns
# Out:
# Index(['Invasive Pneumococcal�, All Ages Disease current week',
#        'Invasive Pneumococcal�, All Ages previous 52 weeks median',
#        'Invasive Pneumococcal�, All Ages previous 52 weeks maximum',
#        'Invasive Pneumococcal�, All Ages cummulative for 2015',
#        'Invasive Pneumococcal�, All Ages cummulative for 2014',
#        'Invasive Pneumococcal�, Age <5 years current week',
#        'Invasive Pneumococcal�, Age <5 years previous 52 weeks median',
#        'Invasive Pneumococcal�, Age <5 years previous 52 weeks maximum',
#        'Invasive Pneumococcal�, Age <5 years cummulative for 2015',
#        'Invasive Pneumococcal�, Age <5 years cummulative for 2014',
#        'Legionellosis current week', 'Legionellosis previous 52 weeks median',
#        'Legionellosis previous 52 weeks maximum',
#        'Legionellosis cummulative for 2015',
#        'Legionellosis cummulative for 2014'],
#       dtype='object')

# %%
legion_14_15= read_legion_2014_2015.drop(columns = ['Invasive Pneumococcal�, All Ages Disease current week',
       'Invasive Pneumococcal�, All Ages previous 52 weeks median',
       'Invasive Pneumococcal�, All Ages previous 52 weeks maximum',
       'Invasive Pneumococcal�, All Ages cummulative for 2015',
       'Invasive Pneumococcal�, All Ages cummulative for 2014',
       'Invasive Pneumococcal�, Age <5 years current week',
       'Invasive Pneumococcal�, Age <5 years previous 52 weeks median',
       'Invasive Pneumococcal�, Age <5 years previous 52 weeks maximum',
       'Invasive Pneumococcal�, Age <5 years cummulative for 2015',
       'Invasive Pneumococcal�, Age <5 years cummulative for 2014',
       'Legionellosis current week', 'Legionellosis previous 52 weeks median',
       'Legionellosis previous 52 weeks maximum',])
legion_14_15.head(2)
# Out:
#            index Legionellosis cummulative for 2015  \
# 0  UNITED STATES                              5,345
# 1    NEW ENGLAND                                288
#
#   Legionellosis cummulative for 2014
# 0                              5,049
# 1                                265

# %% [markdown]
# # Merge all 2015-2010 dataframes together

# %%
# data_frames = [df1, df2, df3] 
#df_merged = reduce(lambda  left,right: pd.merge(left,right,on=['DATE'],
                                          how='outer'), data_frames)

data_frames = [legion_11_10, legion_13_12, legion_14_15]

legion_2010_to_2015 = reduce(lambda left,right: pd.merge(left, right, on=['index'], how='outer'), data_frames)
legion_2010_to_2015.head()

#df_merged = reduce(lambda  left,right: pd.merge(left,right,on=['DATE'],
#                                            how='outer'), data_frames)
# Out:
#            index Legionellosis cummulative for 2011  \
# 0  UNITED STATES                              3,676
# 1    NEW ENGLAND                                394
# 2          Conn.                                 78
# 3          Maine                                 18
# 4          Mass.                                235
#
#   Legionellosis cummulative for 2010 Legionellosis cummulative for 2013  \
# 0                              3,346                              4,548
# 1                                274                                335
# 2                                 56                                 59
# 3                                 12                                 19
# 4                                131                                185
#
#   Legionellosis cummulative for 2012 Legionellosis cummulative for 2015  \
# 0                              3,688                              5,345
# ...

# %%
legion_2010_to_2015.columns = ['state', '2011', '2010', '2013', '2012', '2015', '2014']
legion_2010_to_2015.head()
# Out:
#            state   2011   2010   2013   2012   2015   2014
# 0  UNITED STATES  3,676  3,346  4,548  3,688  5,345  5,049
# 1    NEW ENGLAND    394    274    335    308    288    265
# 2          Conn.     78     56     59     55     52     60
# 3          Maine     18     12     19     18     16     19
# 4          Mass.    235    131    185    173    151    141

# %%
legion_2010_to_2015.to_excel("../data/legion_2010_to_2015.xlsx", index=True)

# %% [markdown]
# # Tidy the Data

# %%
legion_data = pd.read_excel('../data/pop_leg_2010_to_2018.xlsx')
legion_data.head()
# Out:
#           states 2010 Legionnaires_cases   pop_2010  2010 per capita  \
# 0        Alabama                      22  4785437.0         0.000460
# 1         Alaska                       2   713910.0         0.000280
# 2  America Samoa                       N        NaN              NaN
# 3        Arizona                      65  6407172.0         0.001014
# 4       Arkansas                      19  2921964.0         0.000650
#
#   2011 Legionnaires_cases   pop_2011  2011 per capita 2012 Legionnaires_cases  \
# 0                      26  4799069.0         0.000542                      20
# 1                       -   722128.0              NaN                       1
# 2                       N        NaN              NaN                       N
# 3                      42  6472643.0         0.000649                      44
# 4                      14  2940667.0         0.000476                      20
#
#      po_2012  2012 per capita  ... 2015 per capita  2016 Legionnaires_cases  \
# ...

# %%
legion_data = pd.read_excel('../data/pop_leg_2010_to_2018.xlsx')
legion_data_2010 =legion_data.set_index('states', inplace=True)
legion_data_2010 = legion_data.loc[:, '2010 Legionnaires_cases':'2010 per capita']
legion_data_2010.reset_index(inplace=True)
legion_data_2010.head()
# Out:
#           states 2010 Legionnaires_cases   pop_2010  2010 per capita
# 0        Alabama                      22  4785437.0         0.000460
# 1         Alaska                       2   713910.0         0.000280
# 2  America Samoa                       N        NaN              NaN
# 3        Arizona                      65  6407172.0         0.001014
# 4       Arkansas                      19  2921964.0         0.000650

# %%
legion_data = pd.read_excel('../data/pop_leg_2010_to_2018.xlsx')
legion_data_2011 =legion_data.set_index('states', inplace=True)
legion_data_2011 = legion_data.loc[:, '2011 Legionnaires_cases':'2011 per capita']
legion_data_2011.reset_index(inplace=True)
legion_data_2011.head()
# Out:
#           states 2011 Legionnaires_cases   pop_2011  2011 per capita
# 0        Alabama                      26  4799069.0         0.000542
# 1         Alaska                       -   722128.0              NaN
# 2  America Samoa                       N        NaN              NaN
# 3        Arizona                      42  6472643.0         0.000649
# 4       Arkansas                      14  2940667.0         0.000476

# %%
# Out:
# Index(['2011 Legionnaires_cases', 'pop_2011', '2011 per capita'], dtype='object')

# %%
legion_data = pd.read_excel('../data/pop_leg_2010_to_2018.xlsx')
legion_data_2012 =legion_data.set_index('states', inplace=True)
legion_data_2012 = legion_data.loc[:, '2012 Legionnaires_cases':'2012 per capita']
legion_data_2012.reset_index(inplace=True)
legion_data_2012.head()
# Out:
#           states 2012 Legionnaires_cases    po_2012  2012 per capita
# 0        Alabama                      20  4815588.0         0.000415
# 1         Alaska                       1   730443.0         0.000137
# 2  America Samoa                       N        NaN              NaN
# 3        Arizona                      44  6554978.0         0.000671
# 4       Arkansas                      20  2952164.0         0.000677

# %%
legion_data = pd.read_excel('../data/pop_leg_2010_to_2018.xlsx')
legion_data_2013 =legion_data.set_index('states', inplace=True)
legion_data_2013 = legion_data.loc[:, '2013 Legionnaires_cases':'2013 per capita']
legion_data_2013.reset_index(inplace=True)
#legion_data_2013.head()

legion_data = pd.read_excel('../data/pop_leg_2010_to_2018.xlsx')

legion_data_2014 =legion_data.set_index('states', inplace=True)
legion_data_2014 = legion_data.loc[:, '2014 Legionnaires_cases':'2014 per capita']
legion_data_2014.reset_index(inplace=True)
#legion_data_2014.head()

legion_data = pd.read_excel('../data/pop_leg_2010_to_2018.xlsx')

legion_data_2015 =legion_data.set_index('states', inplace=True)
legion_data_2015 = legion_data.loc[:, '2015 Legionnaires_cases':'2015 per capita']
legion_data_2015.reset_index(inplace=True)
#legion_data_2015.head()

legion_data = pd.read_excel('../data/pop_leg_2010_to_2018.xlsx')

legion_data_2016 =legion_data.set_index('states', inplace=True)
legion_data_2016 = legion_data.loc[:, '2016 Legionnaires_cases':'2016 per capita']
legion_data_2016.reset_index(inplace=True)
#legion_data_2016.head()

legion_data = pd.read_excel('../data/pop_leg_2010_to_2018.xlsx')

legion_data_2017 =legion_data.set_index('states', inplace=True)
legion_data_2017 = legion_data.loc[:, '2017 Legionnaires_cases':'2017 per capita']
legion_data_2017.reset_index(inplace=True)
#legion_data_2017.head()

legion_data = pd.read_excel('../data/pop_leg_2010_to_2018.xlsx')

legion_data_2018 =legion_data.set_index('states', inplace=True)
legion_data_2018 = legion_data.loc[:, '2018 Legionnaires_cases':'2018 per capita']
legion_data_2018.reset_index(inplace=True)
#legion_data_2018.head()

# %%
legion_data_2010['year'] = '2010'
legion_data_2011['year'] = '2011'
legion_data_2012['year'] = '2012'
legion_data_2013['year'] = '2013'
legion_data_2014['year'] = '2014'
legion_data_2015['year'] = '2015'
legion_data_2016['year'] = '2016'
legion_data_2017['year'] = '2017'
legion_data_2018['year'] = '2018'

# %%
legion_data_2010.columns =['states', 'cases', 'population', 'per_capita_pop', 'year']
legion_data_2010.head(2)
# Out:
#     states cases  population  per_capita_pop  year
# 0  Alabama    22   4785437.0         0.00046  2010
# 1   Alaska     2    713910.0         0.00028  2010

# %%
legion_data_2011.columns
# Out:
# Index(['states', '2011 Legionnaires_cases', 'pop_2011', '2011 per capita'], dtype='object')

# %%
#school_and_type.columns = ['school', 'type']
legion_data_2011.columns =['states', 'cases', 'population', 'per_capita_pop', 'year']
legion_data_2011.head(2)
# Out:
#     states cases  population  per_capita_pop  year
# 0  Alabama    26   4799069.0        0.000542  2011
# 1   Alaska     -    722128.0             NaN  2011

# %%
legion_data_2012.columns =['states', 'cases', 'population', 'per_capita_pop', 'year']
legion_data_2012.head(2)
# Out:
#     states cases  population  per_capita_pop  year
# 0  Alabama    20   4815588.0        0.000415  2012
# 1   Alaska     1    730443.0        0.000137  2012

# %%
legion_data_2013.columns =['states', 'cases', 'population', 'per_capita_pop', 'year']
legion_data_2013.head(2)
# Out:
#     states cases  population  per_capita_pop  year
# 0  Alabama    41   4830081.0        0.000849  2013
# 1   Alaska     1    737068.0        0.000136  2013

# %%
legion_data_2014.columns =['states', 'cases', 'population', 'per_capita_pop', 'year']
legion_data_2014.head(2)
# Out:
#     states cases  population  per_capita_pop  year
# 0  Alabama    63   4841799.0        0.001301  2014
# 1   Alaska     2    736283.0        0.000272  2014

# %%
legion_data_2015.columns =['states', 'cases', 'population', 'per_capita_pop', 'year']
legion_data_2015.head(2)
# Out:
#     states cases  population  per_capita_pop  year
# 0  Alabama    57   4852347.0        0.001175  2015
# 1   Alaska     -    737498.0             NaN  2015

# %%
legion_data_2016.columns =['states', 'cases', 'population', 'per_capita_pop', 'year']
legion_data_2016.head(2)
# Out:
#     states cases  population  per_capita_pop  year
# 0  Alabama    63   4863525.0        0.001295  2016
# 1   Alaska     1    741456.0        0.000135  2016

# %%
legion_data_2017.columns =['states', 'cases', 'population', 'per_capita_pop', 'year']
legion_data_2017.head(2)
# Out:
#     states cases  population  per_capita_pop  year
# 0  Alabama    66   4874486.0        0.001354  2017
# 1   Alaska     6    739700.0        0.000811  2017

# %%
legion_data_2018.columns =['states', 'cases', 'population', 'per_capita_pop', 'year']
legion_data_2018.head(2)
# Out:
#     states cases  population  per_capita_pop  year
# 0  Alabama    76   4887681.0        0.001555  2018
# 1   Alaska     3    735139.0        0.000408  2018

# %%
#df3.columns = ['column1','column2','column3']

# %%
legion_2010_to_2018 = pd.concat([legion_data_2010, legion_data_2011, legion_data_2012, 
                                legion_data_2013, legion_data_2014, 
                                legion_data_2015, legion_data_2016, 
                                legion_data_2017, legion_data_2018])
legion_2010_to_2018.head()
# Out:
#           states cases  population  per_capita_pop  year
# 0        Alabama    22   4785437.0        0.000460  2010
# 1         Alaska     2    713910.0        0.000280  2010
# 2  America Samoa     N         NaN             NaN  2010
# 3        Arizona    65   6407172.0        0.001014  2010
# 4       Arkansas    19   2921964.0        0.000650  2010

# %%
legion_2010_to_2018 = legion_2010_to_2018.to_excel("../data/legion_2010_to_2018.xlsx", index=True)

# %% [markdown]
# # Medicare data for testing

# %%
#Legionella testing
HCPCS_rows =[]
for chunk in pd.read_csv('../data/Medicare_Provider_Utilization_and_Payment_Data__Physician_and_Other_Supplier_PUF_CY2017.csv', 
                         chunksize = 1000):
    HCPCS_rows.append(chunk[chunk['HCPCS Code'] == '86713']) 
               
                
hcpcs_pay_86713 = pd.concat(HCPCS_rows, ignore_index=True)
print(hcpcs_pay_86713.shape)

hcpcs_pay_86713.head(2)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-133-7bf4a5695f7d> in <module>
#       2 HCPCS_rows =[]
#       3 for chunk in pd.read_csv('../data/Medicare_Provider_Utilization_and_Payment_Data__Physician_and_Other_Supplier_PUF_CY2017.csv',
# ----> 4                          chunksize = 1000):
#       5     HCPCS_rows.append(chunk[chunk['HCPCS Code'] == '86713'])
#       6
#
# /opt/anaconda3/envs/geo/lib/python3.7/site-packages/pandas/io/parsers.py in __next__(self)
#    1105     def __next__(self):
#    1106         try:
# -> 1107             return self.get_chunk()
#    1108         except StopIteration:
#    1109             self.close()
#
# /opt/anaconda3/envs/geo/lib/python3.7/site-packages/pandas/io/parsers.py in get_chunk(self, size)
#    1165                 raise StopIteration
#    1166             size = min(size, self.nrows - self._currow)
# ...

# %%
my_list = ['87278', '86713', '87541']

HCPCS_rows =[]
for chunk in pd.read_csv('../data/Medicare_Provider_Utilization_and_Payment_Data__Physician_and_Other_Supplier_PUF_CY2017.csv', 
                         chunksize = 1000):
    HCPCS_rows.append(chunk[chunk['HCPCS Code'].isin(my_list)]) 
               
                
legion_testing_17 = pd.concat(HCPCS_rows, ignore_index=True)

print(legion_testing_17.shape)
legion_testing_17.head(35)
# Out:
# (35, 26)
#     National Provider Identifier Last Name/Organization Name of the Provider  \
# 0                     1053721373                   TAUSTIN LABORATORIES, LLC
# 1                     1063497451  LABORATORY CORPORATION OF AMERICA HOLDINGS
# 2                     1124442306                    TOTAL DIAGNOSTIX II, LLC
# 3                     1134277494            BIO-REFERENCE LABORATORIES, INC.
# 4                     1134377781                  DIATHERIX LABORATORIES LLC
# 5                     1194769497       CLINICAL PATHOLOGY LABORATORIES, INC.
# 6                     1235234402                    ENZO CLINICAL LABS, INC.
# 7                     1245307818           QUEST DIAGNOSTICS INCORPORATED MD
# 8                     1255314704           LABORATORY CORPORATION OF AMERICA
# 9                     1366479099                          UNILAB CORPORATION
# 10                    1366543795               NORTHWELL HEALTH LABORATORIES
# ...

# %%
legion_testing.columns
# Out:
# Index(['National Provider Identifier',
#        'Last Name/Organization Name of the Provider',
#        'First Name of the Provider', 'Middle Initial of the Provider',
#        'Credentials of the Provider', 'Gender of the Provider',
#        'Entity Type of the Provider', 'Street Address 1 of the Provider',
#        'Street Address 2 of the Provider', 'City of the Provider',
#        'Zip Code of the Provider', 'State Code of the Provider',
#        'Country Code of the Provider', 'Provider Type',
#        'Medicare Participation Indicator', 'Place of Service', 'HCPCS Code',
#        'HCPCS Description', 'HCPCS Drug Indicator', 'Number of Services',
#        'Number of Medicare Beneficiaries',
#        'Number of Distinct Medicare Beneficiary/Per Day Services',
#        'Average Medicare Allowed Amount', 'Average Submitted Charge Amount',
#        'Average Medicare Payment Amount',
#        'Average Medicare Standardized Amount'],
#       dtype='object')

# %%
legion_diagnosis.head(15)

# %% [markdown]
# # Medicare data diagnosis for legionnaires

# %% [markdown]
# 87540
# 87541
# 87542
#
# HCPCS_rows =[]
# for chunk in pd.read_csv('../data/Medicare_Provider_Utilization_and_Payment_Data__Physician_and_Other_Supplier_PUF_CY2017.csv',
#                          chunksize = 1000):
#     HCPCS_rows.append(chunk[chunk['HCPCS Code'] == '87540'])
#
#
# hcpcs_pay_87278 = pd.concat(HCPCS_rows, ignore_index=True)
#
# print(hcpcs_pay_87278.shape)
# hcpcs_pay_87278.head()

# %% [markdown]
# asc_provider = asc_provider.drop(columns= ['Middle Initial of the Provider',
#                             'Credentials of the Provider',
#                             'Street Address 2 of the Provider',
#                            'Medicare Participation Indicator',
#                            'HCPCS Drug Indicator',
#                            'Average Submitted Charge Amount',
#                            'Gender of the Provider',
#                             'First Name of the Provider',
#                             'Average Medicare Payment Amount',
#                             'Average Medicare Standardized Amount',
#                            ])
#
# asc_provider['Zip Code of the Provider'] = asc_provider['Zip Code of the Provider'].apply( lambda x: (5 - len(str(x)))*'0' + str(x) if len(str(x)) <= 5 else (9 - len(str(x)))*'0' + str(x)[:-4]  )
#
# asc_provider.columns = asc_provider.columns.str.replace(' ','_')
#
#
# asc_provider.columns = map(str.lower, asc_provider.columns)
#
#
# df_name = df_name.drop(columns=['average_medicare_payment_amount',
#                                 'outlier_services',
#                                 'average_medicare_outlier_amount',
#                                'average_total_submitted_charges'])
#
# df_name = df_name.rename(columns={'national_provider_identifier':'npi',
#                   'last_name/organization_name_of_the_provider':'name',
#                   'entity_type_of_the_provider':'entity_type',
#                  'street_address_1_of_the_provider':'address',
#                  'city_of_the_provider':'city',
#                  'zip_code_of_the_provider':'zip_code',
#                  'state_code_of_the_provider':'state',
#                  'country_code_of_the_provider':'country',
#                 'number_of_medicare_beneficiaries':'medicare_beneficiaries',
#                 'number_of_distinct_medicare_beneficiary/per_day_services':'medicare_beneficiary/per_day_services'})

# %% [markdown]
# # Medicare Data for 2017 - 2012 - pickle, then add year column to each one and then, merge them together.

# %%
my_list = ['87278', '86713', '87541', '87540', '87542']

HCPCS_rows =[]
for chunk in pd.read_csv('../data/Medicare_Provider_Utilization_and_Payment_Data__Physician_and_Other_Supplier_PUF_CY2017.csv', 
                         chunksize = 1000):
    HCPCS_rows.append(chunk[chunk['HCPCS Code'].isin(my_list)]) 
               
                
legion_testing_17 = pd.concat(HCPCS_rows, ignore_index=True)

print(legion_testing_17.shape)
legion_testing_17.head()
# Out:
# (35, 26)
#    National Provider Identifier Last Name/Organization Name of the Provider  \
# 0                    1053721373                   TAUSTIN LABORATORIES, LLC
# 1                    1063497451  LABORATORY CORPORATION OF AMERICA HOLDINGS
# 2                    1124442306                    TOTAL DIAGNOSTIX II, LLC
# 3                    1134277494            BIO-REFERENCE LABORATORIES, INC.
# 4                    1134377781                  DIATHERIX LABORATORIES LLC
#
#   First Name of the Provider Middle Initial of the Provider  \
# 0                        NaN                            NaN
# 1                        NaN                            NaN
# 2                        NaN                            NaN
# 3                        NaN                            NaN
# 4                        NaN                            NaN
#
#   Credentials of the Provider Gender of the Provider  \
# 0                         NaN                    NaN
# ...

# %%
legion_testing_17['year'] = '2017'
legion_testing_17.head(2)
# Out:
#    National Provider Identifier Last Name/Organization Name of the Provider  \
# 0                    1053721373                   TAUSTIN LABORATORIES, LLC
# 1                    1063497451  LABORATORY CORPORATION OF AMERICA HOLDINGS
#
#   First Name of the Provider Middle Initial of the Provider  \
# 0                        NaN                            NaN
# 1                        NaN                            NaN
#
#   Credentials of the Provider Gender of the Provider  \
# 0                         NaN                    NaN
# 1                         NaN                    NaN
#
#   Entity Type of the Provider Street Address 1 of the Provider  \
# 0                           O                    2868 ACTON RD
# 1                           O                       69 1ST AVE
#
#   Street Address 2 of the Provider City of the Provider  ...  \
# 0                        SUITE 207             VESTAVIA  ...
# 1                              NaN              RARITAN  ...
#
# ...

# %%
my_list = ['87278', '86713', '87541', '87540', '87542']

HCPCS_rows =[]
for chunk in pd.read_csv('../data/Medicare_Provider_Utilization_and_Payment_Data__Physician_and_Other_Supplier_PUF_CY2016.csv', 
                         chunksize = 1000):
    HCPCS_rows.append(chunk[chunk['HCPCS Code'].isin(my_list)]) 
               
                
legion_testing_16 = pd.concat(HCPCS_rows, ignore_index=True)

print(legion_testing_16.shape)
legion_testing_16.head(35)
# Out:
# (28, 26)
#     National Provider Identifier  Last Name/Organization Name of the Provider  \
# 0                     1366543795                NORTHWELL HEALTH LABORATORIES
# 1                     1124085576            QUEST DIAGNOSTICS INCORPORATED MI
# 2                     1740262880            LABORATORY CORPORATION OF AMERICA
# 3                     1538144910   LABORATORY CORPORATION OF AMERICA HOLDINGS
# 4                     1932145778               QUEST DIAGNOSTICS INCORPORATED
# 5                     1225074065  QUEST DIAGNOSTICS CLINICAL LABORATORIES INC
# 6                     1891731626  QUEST DIAGNOSTICS CLINICAL LABORATORIES INC
# 7                     1538144910   LABORATORY CORPORATION OF AMERICA HOLDINGS
# 8                     1588093165                           SHIEL HOLDINGS LLC
# 9                     1366479099                           UNILAB CORPORATION
# 10                    1124442306                     TOTAL DIAGNOSTIX II, LLC
# ...

# %%
legion_testing_16['year'] = '2016'
legion_testing_16.head(2)
# Out:
#    National Provider Identifier Last Name/Organization Name of the Provider  \
# 0                    1932145778              QUEST DIAGNOSTICS INCORPORATED
# 1                    1366479099                          UNILAB CORPORATION
#
#   First Name of the Provider Middle Initial of the Provider  \
# 0                        NaN                            NaN
# 1                        NaN                            NaN
#
#   Credentials of the Provider Gender of the Provider  \
# 0                         NaN                    NaN
# 1                         NaN                    NaN
#
#   Entity Type of the Provider Street Address 1 of the Provider  \
# 0                           O                    1 MALCOLM AVE
# 1                           O               8401 FALLBROOK AVE
#
#   Street Address 2 of the Provider City of the Provider  ...  \
# 0                              NaN            TETERBORO  ...
# 1                              NaN           WEST HILLS  ...
#
# ...

# %%
my_list = ['87278', '86713', '87541', '87540', '87542']

HCPCS_rows =[]
for chunk in pd.read_csv('../data/Medicare_Provider_Utilization_and_Payment_Data__Physician_and_Other_Supplier_PUF_CY2015.csv', 
                         chunksize = 1000):
    HCPCS_rows.append(chunk[chunk['HCPCS Code'].isin(my_list)]) 
               
                
legion_testing_15 = pd.concat(HCPCS_rows, ignore_index=True)

print(legion_testing_15.shape)
legion_testing_15.head(35)
# Out:
# (29, 26)
#     National Provider Identifier  \
# 0                     1245307818
# 1                     1457341851
# 2                     1225074065
# 3                     1588093165
# 4                     1396746673
# 5                     1366543795
# 6                     1235234402
# 7                     1063497451
# 8                     1083613376
# 9                     1447296272
# 10                    1134277494
# 11                    1346233277
# 12                    1811997711
# 13                    1891731626
# 14                    1740262880
# 15                    1932145778
# 16                    1134377781
# 17                    1366543795
# 18                    1538144910
# 19                    1265418669
# 20                    1497773337
# 21                    1538105366
# 22                    1255314704
# 23                    1194769497
# 24                    1043256886
# 25                    1932184322
# 26                    1366479099
# ...

# %%
legion_testing_15['year'] = '2015'
legion_testing_15.head(2)
# Out:
#    National Provider Identifier Last Name/Organization Name of the Provider  \
# 0                    1245307818           QUEST DIAGNOSTICS INCORPORATED MD
# 1                    1457341851       PHYSICIAN'S AUTOMATED LABORATORY, INC
#
#   First Name of the Provider Middle Initial of the Provider  \
# 0                        NaN                            NaN
# 1                        NaN                            NaN
#
#   Credentials of the Provider Gender of the Provider  \
# 0                         NaN                    NaN
# 1                         NaN                    NaN
#
#   Entity Type of the Provider Street Address 1 of the Provider  \
# 0                           O           1901 SULPHUR SPRING RD
# 1                           O                      820 34TH ST
#
#   Street Address 2 of the Provider City of the Provider  ...  \
# 0                              NaN            BALTIMORE  ...
# 1                        SUITE 103          BAKERSFIELD  ...
#
# ...

# %%
my_list = ['87278', '86713', '87541', '87540', '87542']

HCPCS_rows =[]
for chunk in pd.read_csv('../data/Medicare_Provider_Utilization_and_Payment_Data__Physician_and_Other_Supplier_PUF_CY2014.csv', 
                         chunksize = 1000):
    HCPCS_rows.append(chunk[chunk['HCPCS Code'].isin(my_list)]) 
               
                
legion_testing_14 = pd.concat(HCPCS_rows, ignore_index=True)

print(legion_testing_14.shape)
legion_testing_14.head(35)
# Out:
# (27, 26)
#     National Provider Identifier  \
# 0                     1932145778
# 1                     1366479099
# 2                     1124085576
# 3                     1538105366
# 4                     1225074065
# 5                     1245307818
# 6                     1396746673
# 7                     1063497451
# 8                     1811997711
# 9                     1538144910
# 10                    1235234402
# 11                    1366543795
# 12                    1891731626
# 13                    1740262880
# 14                    1457341851
# 15                    1932166386
# 16                    1134277494
# 17                    1750374088
# 18                    1194769497
# 19                    1932184322
# 20                    1497773337
# 21                    1255314704
# 22                    1205872041
# 23                    1134377781
# 24                    1669515391
# 25                    1881630614
# 26                    1619913449
#
# ...

# %%
legion_testing_14['year'] = '2014'
legion_testing_14.head(2)
# Out:
#    National Provider Identifier Last Name/Organization Name of the Provider  \
# 0                    1932145778              QUEST DIAGNOSTICS INCORPORATED
# 1                    1366479099                          UNILAB CORPORATION
#
#   First Name of the Provider Middle Initial of the Provider  \
# 0                        NaN                            NaN
# 1                        NaN                            NaN
#
#   Credentials of the Provider Gender of the Provider  \
# 0                         NaN                    NaN
# 1                         NaN                    NaN
#
#   Entity Type of the Provider Street Address 1 of the Provider  \
# 0                           O                    1 MALCOLM AVE
# 1                           O               8401 FALLBROOK AVE
#
#   Street Address 2 of the Provider City of the Provider  ...  \
# 0                              NaN            TETERBORO  ...
# 1                              NaN           WEST HILLS  ...
#
# ...

# %%
test = pd.read_csv('../data/Medicare_Provider_Utilization_and_Payment_Data__Physician_and_Other_Supplier_CY2013.csv')
test.head(3)
# Out:
# /opt/anaconda3/envs/geo/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3063: DtypeWarning: Columns (10) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#    National Provider Identifier  Last Name/Organization Name First Name  \
# 0                     1104813138                     SERSHON      PETER
# 1                     1184755308                       DAVIS        AMY
# 2                     1972533834                     SCHMIDT       MARY
#
#   Middle Initial Credentials Gender Entity Code     Street Address 1  \
# 0              D        M.D.      M           I       360 SHERMAN ST
# 1              B          MD      F           I  121 PRATT DR STE 1A
# 2              S        M.D.      F           I  3003 W GOOD HOPE RD
#
#   Street Address 2        City  ... HCPCS_DRUG_INDICATOR LINE_SRVC_CNT  \
# 0        SUITE 450  SAINT PAUL  ...                    N          23.0
# ...

# %%
test.columns
## Will need to change HCPC before merge 2013
# Out:
# Index(['National Provider Identifier ', 'Last Name/Organization Name',
#        'First Name', 'Middle Initial', 'Credentials', 'Gender', 'Entity Code',
#        'Street Address 1', 'Street Address 2', 'City', 'Zip Code',
#        'State Code', 'Country Code', 'Provider Type', 'Medicare Participation',
#        'Place of Service', 'HCPCS_CODE', 'HCPCS_DESCRIPTION',
#        'HCPCS_DRUG_INDICATOR', 'LINE_SRVC_CNT', 'BENE_UNIQUE_CNT',
#        'BENE_DAY_SRVC_CNT', 'AVERAGE_MEDICARE_ALLOWED_AMT',
#        'STDEV_MEDICARE_ALLOWED_AMT', 'AVERAGE_SUBMITTED_CHRG_AMT',
#        'STDEV_SUBMITTED_CHRG_AMT', 'AVERAGE_MEDICARE_PAYMENT_AMT',
#        'STDEV_MEDICARE_PAYMENT_AMT'],
#       dtype='object')

# %%
my_list = ['87278', '86713', '87541', '87540', '87542']

HCPCS_rows =[]
for chunk in pd.read_csv('../data/Medicare_Provider_Utilization_and_Payment_Data__Physician_and_Other_Supplier_CY2013.csv', 
                         chunksize = 1000):
    HCPCS_rows.append(chunk[chunk['HCPCS_CODE'].isin(my_list)]) 
               
legion_testing_13 = pd.concat(HCPCS_rows, ignore_index=True)

print(legion_testing_13.shape)
legion_testing_13.head()
# Out:
# (28, 28)
#    National Provider Identifier                  Last Name/Organization Name  \
# 0                     1497773337            REGIONAL MEDICAL LABORATORY, INC
# 1                     1669515391             ACCURATE DIAGNOSTICS LABS, INC.
# 2                     1063497451  LABORATORY CORPORATION OF AMERICA HOLDINGS
# 3                     1235234402                    ENZO CLINICAL LABS, INC.
# 4                     1932145778              QUEST DIAGNOSTICS INCORPORATED
#
#   First Name Middle Initial Credentials Gender Entity Code  \
# 0        NaN            NaN         NaN    NaN           O
# 1        NaN            NaN         NaN    NaN           O
# 2        NaN            NaN         NaN    NaN           O
# 3        NaN            NaN         NaN    NaN           O
# 4        NaN            NaN         NaN    NaN           O
#
#      Street Address 1 Street Address 2         City  ... HCPCS_DRUG_INDICATOR  \
# ...

# %%
legion_testing_13['year'] = '2013'
legion_testing_13.head(2)
# Out:
#    National Provider Identifier        Last Name/Organization Name First Name  \
# 0                     1497773337  REGIONAL MEDICAL LABORATORY, INC        NaN
# 1                     1669515391   ACCURATE DIAGNOSTICS LABS, INC.        NaN
#
#   Middle Initial Credentials Gender Entity Code    Street Address 1  \
# 0            NaN         NaN    NaN           O    1923 S UTICA AVE
# 1            NaN         NaN    NaN           O  180 STATE ROUTE 27
#
#   Street Address 2    City  ... Number of Services  \
# 0              NaN   TULSA  ...               22.0
# 1              NaN  EDISON  ...               49.3
#
#   Number of Medicare Beneficiaries  \
# 0                             22.0
# 1                             17.0
#
#   Number of Medicare Beneficiary/Day Services Average Medicare Allowed Amount  \
# 0                                        22.0                       21.040000
# 1                                        18.0                       21.039959
#
# ...

# %% [markdown]
# # FIX Columns for year 2013 before merge.

# %%
legion_testing_13 = legion_testing_13.rename(columns={'national_provider_identifier':'npi', 'HCPCS_CODE':'HCPCS Code', 'HCPCS_DESCRIPTION':'HCPCS Description',
       'HCPCS_DRUG_INDICATOR':'HCPCS Drug Indicator', 'LINE_SRVC_CNT':'Number of Services', 'BENE_UNIQUE_CNT':'Number of Medicare Beneficiaries',
       'BENE_DAY_SRVC_CNT':'Number of Medicare Beneficiary/Day Services', 'AVERAGE_MEDICARE_ALLOWED_AMT':'Average Medicare Allowed Amount',
       'STDEV_MEDICARE_ALLOWED_AMT':'Standard Deviation of Medicare Allowed Amount', 'AVERAGE_SUBMITTED_CHRG_AMT':'Average Submitted Charge Amount',
       'STDEV_SUBMITTED_CHRG_AMT':'Standard Deviation of Submitted Charge Amount', 'AVERAGE_MEDICARE_PAYMENT_AMT':'Average Medicare Payment Amount',
       'STDEV_MEDICARE_PAYMENT_AMT': 'Standard Deviation of Medicare Payment Amount'})
legion_testing_13.head()
# Out:
#    National Provider Identifier                  Last Name/Organization Name  \
# 0                     1497773337            REGIONAL MEDICAL LABORATORY, INC
# 1                     1669515391             ACCURATE DIAGNOSTICS LABS, INC.
# 2                     1063497451  LABORATORY CORPORATION OF AMERICA HOLDINGS
# 3                     1235234402                    ENZO CLINICAL LABS, INC.
# 4                     1932145778              QUEST DIAGNOSTICS INCORPORATED
#
#   First Name Middle Initial Credentials Gender Entity Code  \
# 0        NaN            NaN         NaN    NaN           O
# 1        NaN            NaN         NaN    NaN           O
# 2        NaN            NaN         NaN    NaN           O
# 3        NaN            NaN         NaN    NaN           O
# 4        NaN            NaN         NaN    NaN           O
#
#      Street Address 1 Street Address 2         City  ... Number of Services  \
# ...

# %%
legion_testing_13 = legion_testing_13.rename(columns={'national_provider_identifier':'npi', 'HCPCS_CODE':'HCPCS Code', 'HCPCS_DESCRIPTION':'HCPCS Description',
       'HCPCS_DRUG_INDICATOR':'HCPCS Drug Indicator', 'LINE_SRVC_CNT':'Number of Services', 'BENE_UNIQUE_CNT':'Number of Medicare Beneficiaries',
       'BENE_DAY_SRVC_CNT':'Number of Medicare Beneficiary/Day Services', 'AVERAGE_MEDICARE_ALLOWED_AMT':'Average Medicare Allowed Amount',
       'STDEV_MEDICARE_ALLOWED_AMT':'Standard Deviation of Medicare Allowed Amount', 'AVERAGE_SUBMITTED_CHRG_AMT':'Average Submitted Charge Amount',
       'STDEV_SUBMITTED_CHRG_AMT':'Standard Deviation of Submitted Charge Amount', 'AVERAGE_MEDICARE_PAYMENT_AMT':'Average Medicare Payment Amount',
       'STDEV_MEDICARE_PAYMENT_AMT': 'Standard Deviation of Medicare Payment Amount'],
      dtype='object')

Index(['HCPCS Code', 'HCPCS Description',
       'HCPCS Drug Indicator', 'Number of Services',
       'Number of Medicare Beneficiaries',
       'Number of Medicare Beneficiary/Day Services',
       'Average Medicare Allowed Amount',
       'Standard Deviation of Medicare Allowed Amount',
       'Average Submitted Charge Amount',
       'Standard Deviation of Submitted Charge Amount',
       'Average Medicare Payment Amount',
       'Standard Deviation of Medicare Payment Amount'],
      dtype='object')

# %%
my_list = ['87278', '86713', '87541', '87540', '87542']

HCPCS_rows =[]
for chunk in pd.read_csv('../data/Medicare_Provider_Utilization_and_Payment_Data__Physician_and_Other_Supplier_CY2012.csv', 
                         chunksize = 1000):
    HCPCS_rows.append(chunk[chunk['HCPCS Code'].isin(my_list)]) 
               
                
legion_testing_12 = pd.concat(HCPCS_rows, ignore_index=True)

print(legion_testing_12.shape)
legion_testing_12.head(35)
# Out:
# (28, 28)
#     National Provider Identifier                  Last Name/Organization Name  \
# 0                     1245307818            QUEST DIAGNOSTICS INCORPORATED MD
# 1                     1124085576            QUEST DIAGNOSTICS INCORPORATED MI
# 2                     1518903350  QUEST DIAGNOSTICS CLINICAL LABORATORIES INC
# 3                     1497773337             REGIONAL MEDICAL LABORATORY, INC
# 4                     1134277494             BIO-REFERENCE LABORATORIES, INC.
# 5                     1346233277              SOLSTAS LAB PARTNERS GROUP, LLC
# 6                     1740262880            LABORATORY CORPORATION OF AMERICA
# 7                     1225074065          QUEST DIAGNOSTICS CLINICAL LAB INC.
# 8                     1790721538  QUEST DIAGNOSTICS CLINICAL LABORATORIES INC
# 9                     1538144910   LABORATORY CORPORATION OF AMERICA HOLDINGS
# 10                    1659352276            LABORATORY CORPORATION OF AMERICA
# ...

# %% [markdown]
# # Clean up 2012 columns before merge.

# %%
legion_testing_12.columns
# Out:
# Index(['National Provider Identifier', 'Last Name/Organization Name',
#        'First Name', 'Middle Initial', 'Credentials', 'Gender', 'Entity Code',
#        'Street Address 1', 'Street Address 2', 'City', 'Zip Code',
#        'State Code', 'Country Code', 'Provider Type', 'Medicare Participation',
#        'Place of Service', 'HCPCS Code', 'HCPCS Description',
#        'HCPCS Drug Indicator', 'Number of Services',
#        'Number of Medicare Beneficiaries',
#        'Number of Medicare Beneficiary/Day Services',
#        'Average Medicare Allowed Amount',
#        'Standard Deviation of Medicare Allowed Amount',
#        'Average Submitted Charge Amount',
#        'Standard Deviation of Submitted Charge Amount',
#        'Average Medicare Payment Amount',
#        'Standard Deviation of Medicare Payment Amount', 'year'],
#       dtype='object')

# %%
legion_testing_16.columns
# Out:
# Index(['National Provider Identifier',
#        'Last Name/Organization Name of the Provider',
#        'First Name of the Provider', 'Middle Initial of the Provider',
#        'Credentials of the Provider', 'Gender of the Provider',
#        'Entity Type of the Provider', 'Street Address 1 of the Provider',
#        'Street Address 2 of the Provider', 'City of the Provider',
#        'Zip Code of the Provider', 'State Code of the Provider',
#        'Country Code of the Provider', 'Provider Type of the Provider',
#        'Medicare Participation Indicator', 'Place of Service', 'HCPCS Code',
#        'HCPCS Description',
#        'Identifies HCPCS As Drug Included in the ASP Drug List',
#        'Number of Services', 'Number of Medicare Beneficiaries',
#        'Number of Distinct Medicare Beneficiary/Per Day Services',
#        'Average Medicare Allowed Amount', 'Average Submitted Charge Amount',
#        'Average Medicare Payment Amount',
# ...

# %%
legion_testing_12.rename(columns={'Last Name/Organization Name':'Last Name/Organization Name of the Provider',
       'First Name':'First Name of the Provider', 'Middle Initial':'Middle Initial of the Provider', 'Credentials':'Credentials of the Provider', 'Gender':'Gender of the Provider', 'Entity Code':'Entity Type of the Provider',
       'Street Address 1':'Street Address 1 of the Provider', 'Street Address 2':'Street Address 2 of the Provider', 'City':'City of the Provider', 'Zip Code':'Zip Code of the Provider',
       'State Code':'State Code of the Provider', 'Country Code':'Country Code of the Provider', 'Provider Type':'Provider Type of the Provider', 'Medicare Participation':'Medicare Participation Indicator',
       'HCPCS Drug Indicator':'Identifies HCPCS As Drug Included in the ASP Drug List', 
       'Number of Medicare Beneficiary/Day Services':'Number of Distinct Medicare Beneficiary/Per Day Services'})
# Out:
#     National Provider Identifier  Last Name/Organization Name of the Provider  \
# 0                     1245307818            QUEST DIAGNOSTICS INCORPORATED MD
# 1                     1124085576            QUEST DIAGNOSTICS INCORPORATED MI
# 2                     1518903350  QUEST DIAGNOSTICS CLINICAL LABORATORIES INC
# 3                     1497773337             REGIONAL MEDICAL LABORATORY, INC
# 4                     1134277494             BIO-REFERENCE LABORATORIES, INC.
# 5                     1346233277              SOLSTAS LAB PARTNERS GROUP, LLC
# 6                     1740262880            LABORATORY CORPORATION OF AMERICA
# 7                     1225074065          QUEST DIAGNOSTICS CLINICAL LAB INC.
# 8                     1790721538  QUEST DIAGNOSTICS CLINICAL LABORATORIES INC
# 9                     1538144910   LABORATORY CORPORATION OF AMERICA HOLDINGS
# 10                    1659352276            LABORATORY CORPORATION OF AMERICA
# ...

# %%
legion_testing_12['year'] = '2012'
legion_testing_12.head(1)
# Out:
#    National Provider Identifier        Last Name/Organization Name First Name  \
# 0                    1245307818  QUEST DIAGNOSTICS INCORPORATED MD        NaN
#
#   Middle Initial Credentials Gender Entity Code        Street Address 1  \
# 0            NaN         NaN    NaN           O  1901 SULPHUR SPRING RD
#
#   Street Address 2       City  ... Number of Services  \
# 0              NaN  BALTIMORE  ...               94.0
#
#   Number of Medicare Beneficiaries  \
# 0                               39
#
#   Number of Medicare Beneficiary/Day Services Average Medicare Allowed Amount  \
# 0                                          58                           21.67
#
#   Standard Deviation of Medicare Allowed Amount  \
# 0                                           0.0
#
#   Average Submitted Charge Amount  \
# 0                      110.686064
#
#   Standard Deviation of Submitted Charge Amount  \
# 0                                      3.388146
#
# ...

# %% [markdown]
# # Join all the dataframes and drop columns

# %%
medicare_data = pd.concat([legion_testing_17, legion_testing_16, legion_testing_15, legion_testing_14, legion_testing_13, legion_testing_12])

medicare_data.shape
medicare_data.head()
# Out:
#    National Provider Identifier Last Name/Organization Name of the Provider  \
# 0                  1.053721e+09                   TAUSTIN LABORATORIES, LLC
# 1                  1.063497e+09  LABORATORY CORPORATION OF AMERICA HOLDINGS
# 2                  1.124442e+09                    TOTAL DIAGNOSTIX II, LLC
# 3                  1.134277e+09            BIO-REFERENCE LABORATORIES, INC.
# 4                  1.134378e+09                  DIATHERIX LABORATORIES LLC
#
#   First Name of the Provider Middle Initial of the Provider  \
# 0                        NaN                            NaN
# 1                        NaN                            NaN
# 2                        NaN                            NaN
# 3                        NaN                            NaN
# 4                        NaN                            NaN
#
#   Credentials of the Provider Gender of the Provider  \
# 0                         NaN                    NaN
# ...

# %%
medicare_data.columns
# Out:
# Index(['National Provider Identifier',
#        'Last Name/Organization Name of the Provider',
#        'First Name of the Provider', 'Middle Initial of the Provider',
#        'Credentials of the Provider', 'Gender of the Provider',
#        'Entity Type of the Provider', 'Street Address 1 of the Provider',
#        'Street Address 2 of the Provider', 'City of the Provider',
#        'Zip Code of the Provider', 'State Code of the Provider',
#        'Country Code of the Provider', 'Provider Type',
#        'Medicare Participation Indicator', 'Place of Service', 'HCPCS Code',
#        'HCPCS Description', 'HCPCS Drug Indicator', 'Number of Services',
#        'Number of Medicare Beneficiaries',
#        'Number of Distinct Medicare Beneficiary/Per Day Services',
#        'Average Medicare Allowed Amount', 'Average Submitted Charge Amount',
#        'Average Medicare Payment Amount',
#        'Average Medicare Standardized Amount', 'year',
#        'Provider Type of the Provider',
# ...

# %%
medicare_data = medicare_data.drop(columns=['First Name of the Provider', 'Middle Initial of the Provider',
       'Street Address 2 of the Provider', 
       'Country Code of the Provider', 
       'Medicare Participation Indicator', 
       'Identifies HCPCS As Drug Included in the ASP Drug List',
       'First Name', 'Middle Initial', 'Credentials', 'Gender', 
       'Street Address 2', 'Country Code', 'Medicare Participation',
       'Standard Deviation of Medicare Allowed Amount',
       'Standard Deviation of Submitted Charge Amount'])
                   
medicare_data.head()
# Out:
#    National Provider Identifier Last Name/Organization Name of the Provider  \
# 0                  1.053721e+09                   TAUSTIN LABORATORIES, LLC
# 1                  1.063497e+09  LABORATORY CORPORATION OF AMERICA HOLDINGS
# 2                  1.124442e+09                    TOTAL DIAGNOSTIX II, LLC
# 3                  1.134277e+09            BIO-REFERENCE LABORATORIES, INC.
# 4                  1.134378e+09                  DIATHERIX LABORATORIES LLC
#
#   Credentials of the Provider Gender of the Provider  \
# 0                         NaN                    NaN
# 1                         NaN                    NaN
# 2                         NaN                    NaN
# 3                         NaN                    NaN
# 4                         NaN                    NaN
#
#   Entity Type of the Provider Street Address 1 of the Provider  \
# 0                           O                    2868 ACTON RD
# ...

# %%
medicare_data = medicare_data.drop(columns=['Credentials of the Provider', 'Gender of the Provider', 'Standard Deviation of Medicare Payment Amount'])
medicare_data.head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-120-cd32c0e9b05e> in <module>
# ----> 1 medicare_data = medicare_data.drop(columns=['Credentials of the Provider', 'Gender of the Provider', 'Standard Deviation of Medicare Payment Amount'])
#       2 medicare_data.head()
#
# /opt/anaconda3/envs/geo/lib/python3.7/site-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3995             level=level,
#    3996             inplace=inplace,
# -> 3997             errors=errors,
#    3998         )
#    3999
#
# /opt/anaconda3/envs/geo/lib/python3.7/site-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3934         for axis, labels in axes.items():
#    3935             if labels is not None:
# ...

# %%
medicare_data.tail(40)
# Out:
#     National Provider Identifier Last Name/Organization Name of the Provider  \
# 16                           NaN                                         NaN
# 17                           NaN                                         NaN
# 18                           NaN                                         NaN
# 19                           NaN                                         NaN
# 20                           NaN                                         NaN
# 21                           NaN                                         NaN
# 22                           NaN                                         NaN
# 23                           NaN                                         NaN
# 24                           NaN                                         NaN
# 25                           NaN                                         NaN
# 26                           NaN                                         NaN
# ...

# %% [markdown]
# # Population data

# %%
state_pop = pd.read_excel("../data/state_pop_data.xlsx")
state_pop.head(10)
# Out:
#                  States        2010        2011        2012        2013  \
# 0               Alabama   4785437.0   4799069.0   4815588.0   4830081.0
# 1                Alaska    713910.0    722128.0    730443.0    737068.0
# 2               Arizona   6407172.0   6472643.0   6554978.0   6632764.0
# 3              Arkansas   2921964.0   2940667.0   2952164.0   2959400.0
# 4            California  37319502.0  37638369.0  37948800.0  38260787.0
# 5              Colorado   5047349.0   5121108.0   5192647.0   5269035.0
# 6           Connecticut   3579114.0   3588283.0   3594547.0   3594841.0
# 7              Delaware    899593.0    907381.0    915179.0    923576.0
# 8  District of Columbia    605226.0    619800.0    634924.0    650581.0
# 9               Florida  18845537.0  19053237.0  19297822.0  19545621.0
#
#          2014        2015        2016        2017        2018        2019
# 0   4841799.0   4852347.0   4863525.0   4874486.0   4887681.0   4903185.0
# ...

# %%
legion_table = pd.read_csv('../data/NNDSS_-_table_II._Invasive_Pneumococcal_to_Legionellosis.csv')
legion_table.head()
# Out:
#   Reporting Area  MMWR Year  MMWR Week  \
# 0  UNITED STATES       2014          1
# 1    NEW ENGLAND       2014          1
# 2  MID. ATLANTIC       2014          1
# 3   E.N. CENTRAL       2014          1
# 4   W.N. CENTRAL       2014          1
#
#    Invasive Pneumococcal disease, All ages, Current week  \
# 0                                              169.0
# 1                                                4.0
# 2                                               11.0
# 3                                               26.0
# 4                                                6.0
#
#   Invasive Pneumococcal disease, All ages, Current week, flag  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
# ...
